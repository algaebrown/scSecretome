# %%
library(ReactomePA)
# Out:
# Registered S3 method overwritten by 'enrichplot':
#   method               from
#   fortify.enrichResult DOSE
# ReactomePA v1.28.0  For help: https://guangchuangyu.github.io/ReactomePA
#
# If you use ReactomePA in published research, please cite:
# Guangchuang Yu, Qing-Yu He. ReactomePA: an R/Bioconductor package for reactome pathway analysis and visualization. Molecular BioSystems 2016, 12(2):477-479

# %%
path <- "cell12_symbol.txt"
print(path)
 
conn <- file(path,open="r")
lines <- readLines(conn)

close(conn)
# Out:
# [1] "cell12_symbol.txt"
# Error in eval(expr, envir, enclos): (list) object cannot be coerced to type 'integer'
# Traceback:

# %%
parse_genelist <- function(file_lines){
    gene_list <- list()
    for (i in length(file_lines)){
        gene_list.append()
    }
}

# %%
reactome_enrichment <- function(cell_id){
    de = as.integer(as.vector(unlist(strsplit(lines[cell_id+1], ','))))
    
    # run enrichment analysis
    x <- enrichPathway(gene=de,pvalueCutoff=0.05, readable=T)
    
    return(x)
}

# %%
x <- reactome_enrichment(0)
barplot(x, showCategory=20)
# Out:
# plot without title

# %%
cnetplot(x)
# Out:
# plot without title

# %%
emapplot(x)
# Out:
# plot without title

# %%
require(clusterProfiler)
data(gcSample)
res <- compareCluster(gcSample, fun="enrichPathway")
dotplot(res)
# Out:
# Loading required package: clusterProfiler
# clusterProfiler v3.12.0  For help: https://guangchuangyu.github.io/software/clusterProfiler
#
# If you use clusterProfiler in published research, please cite:
# Guangchuang Yu, Li-Gen Wang, Yanyan Han, Qing-Yu He. clusterProfiler: an R package for comparing biological themes among gene clusters. OMICS: A Journal of Integrative Biology. 2012, 16(5):284-287.
# plot without title

# %%
# Out:
# $X1
#   [1] "4597"   "7111"   "5266"   "2175"   "755"    "23046"  "3931"   "6770"
#   [9] "993"    "229"    "55800"  "10232"  "5871"   "4771"   "2173"   "27239"
#  [17] "5167"   "3757"   "119"    "7850"   "51678"  "653"    "6364"   "51442"
#  [25] "55056"  "671"    "366"    "5080"   "3899"   "9369"   "8685"   "3101"
#  [33] "2005"   "10874"  "8715"   "3827"   "8292"   "6665"   "9355"   "2709"
#  [41] "2840"   "8581"   "11184"  "5319"   "3559"   "7136"   "1608"   "8710"
#  [49] "2558"   "22808"  "6541"   "1137"   "2208"   "8092"   "28513"  "3595"
#  [57] "10001"  "6564"   "30848"  "4857"   "4115"   "8326"   "9863"   "8814"
#  [65] "1448"   "2921"   "9942"   "64211"  "7368"   "3024"   "923"    "333"
#  [73] "6317"   "3868"   "10411"  "22861"  "8707"   "932"    "4109"   "9362"
#  [81] "29851"  "3159"   "2529"   "27077"  "27180"  "11283"  "2780"   "5467"
#  [89] "8793"   "4902"   "8828"   "3697"   "259197" "8817"   "10733"  "84786"
# ...
