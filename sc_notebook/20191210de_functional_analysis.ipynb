# %% [markdown]
# # DE gene functional analysis

# %%
# load annotation and packages needed
import sys
sys.path.append('/home/hsher/scSecretome')
from scSecretome.secM import *
from scSecretome.annot import *
from scSecretome.de import *
import scanpy as sc

# read processed, filtered, normalized single cell data.
pellin_cd34 = sc.read('/home/hsher/processed_single_cell_data/pellin_cd34.h5ad')
pellin_lin = sc.read('/home/hsher/processed_single_cell_data/pellin_lin.h5ad')
pellin_int = sc.read('/home/hsher/processed_single_cell_data/pellin_bbknn.h5ad')
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.

# %%
de_analysis(pellin_cd34, 'louvain')
sc.pl.rank_genes_groups_dotplot(pellin_cd34, key='rank_genes_groups_filtered')
# Out:
# WARNING: No genes found for group 0
# WARNING: No genes found for group 1
# WARNING: No genes found for group 2
# WARNING: No genes found for group 4
# WARNING: No genes found for group 6
# WARNING: No genes found for group 9
# WARNING: No genes found for group 12
# WARNING: dendrogram data not found (using key=dendrogram_louvain). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: 3, 5, 7, etc.

# %%
sc.pl.rank_genes_groups_dotplot(pellin_cd34) # without 3-fold filtering

# %%
len(all_de_genes(pellin_cd34))
# Out:
# 890

# %%
s = symbol_to_id(de_gene_to_dict(pellin_cd34), all_de_genes(pellin_cd34))

# %%
write_to_file(s, 'pellin_34_de')

# %%
de_analysis(pellin_lin, 'louvain')
len(all_de_genes(pellin_lin))
s = symbol_to_id(de_gene_to_dict(pellin_lin), all_de_genes(pellin_lin))
write_to_file(s, 'pellin_lin_de')

# %%
de_analysis(pellin_int, 'louvain')
len(all_de_genes(pellin_int))
s = symbol_to_id(de_gene_to_dict(pellin_int), all_de_genes(pellin_int))
write_to_file(s, 'pellin_int_de')

# %%
wolock = sc.read('/home/hsher/processed_single_cell_data/wolock_mapped.h5ad')
tik = sc.read('/home/hsher/processed_single_cell_data/tikhonova_mapped.h5ad')
bary = sc.read('/home/hsher/processed_single_cell_data/baryawno_mapped.h5ad')
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
# fold change is based on this
tik.raw = tik
tik.var_names_make_unique()
de_analysis(tik, 'louvain')
len(all_de_genes(tik))
s = symbol_to_id(de_gene_to_dict(tik), all_de_genes(tik))
write_to_file(s, 'tikhonova_de')
